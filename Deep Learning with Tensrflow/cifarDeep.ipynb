# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, regularizers, optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
# hyperparameter
EPOCHS=50
NUM_CLASSES = 10
BATCH_SIZE = 128

# %%
def load_data():
    (x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()
    x_train = x_train.astype('float32')
    x_test = x_test.astype('float32')
 
    #normalize 
    mean = np.mean(x_train,axis=(0,1,2,3))
    std = np.std(x_train,axis=(0,1,2,3))
    x_train = (x_train-mean)/(std+1e-7)
    x_test = (x_test-mean)/(std+1e-7)
 
    y_train =  tf.keras.utils.to_categorical(y_train,NUM_CLASSES)
    y_test =  tf.keras.utils.to_categorical(y_test,NUM_CLASSES)

    return x_train, y_train, x_test, y_test

# %% [markdown]
# 1st module: (CONV+CONV+MaxPool+DropOut)
#
# 2nd module: (CONV+CONV+MaxPool+DropOut)
#
# 3rd module: (CONV+CONV+MaxPool+DropOut)

# %%
def build_model(): 
    model = models.Sequential()
    
    #1st blocl
    model.add(layers.Conv2D(32, (3,3), padding='same', input_shape=x_train.shape[1:], activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(32, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D(pool_size=(2,2)))
    model.add(layers.Dropout(0.2))

    #2nd block
    model.add(layers.Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D(pool_size=(2,2)))
    model.add(layers.Dropout(0.3))

    #3d block 
    model.add(layers.Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D(pool_size=(2,2)))
    model.add(layers.Dropout(0.4))

    #dense  
    model.add(layers.Flatten())
    model.add(layers.Dense(NUM_CLASSES, activation='softmax'))
    return model

# %%
(x_train, y_train, x_test, y_test) = load_data()
model = build_model()
model.summary()
model.compile(loss='categorical_crossentropy', optimizer='RMSprop', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization_4 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_5 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 10)                20490
#
# =================================================================
# Total params: 309,290
# Trainable params: 308,394
# Non-trainable params: 896
# _________________________________________________________________

# %%
#train
batch_size = 64
model.fit(x_train, y_train, batch_size=batch_size,
    epochs=EPOCHS, validation_data=(x_test,y_test)) 
score = model.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
print("\nTest score:", score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/50
# 782/782 [==============================] - 19s 20ms/step - loss: 1.7447 - accuracy: 0.4771 - val_loss: 1.3086 - val_accuracy: 0.5804
# Epoch 2/50
# 782/782 [==============================] - 15s 20ms/step - loss: 1.0828 - accuracy: 0.6495 - val_loss: 0.9804 - val_accuracy: 0.6754
# Epoch 3/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.8755 - accuracy: 0.7113 - val_loss: 0.8837 - val_accuracy: 0.7230
# Epoch 4/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.7476 - accuracy: 0.7437 - val_loss: 0.7430 - val_accuracy: 0.7575
# Epoch 5/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.6639 - accuracy: 0.7719 - val_loss: 0.6537 - val_accuracy: 0.7753
# Epoch 6/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.5997 - accuracy: 0.7933 - val_loss: 0.5801 - val_accuracy: 0.8036
# Epoch 7/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.5480 - accuracy: 0.8101 - val_loss: 0.6447 - val_accuracy: 0.7833
# Epoch 8/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.5129 - accuracy: 0.8219 - val_loss: 0.5552 - val_accuracy: 0.8180
# Epoch 9/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.4791 - accuracy: 0.8346 - val_loss: 0.6146 - val_accuracy: 0.7969
# Epoch 10/50
# 782/782 [==============================] - 14s 19ms/step - loss: 0.4480 - accuracy: 0.8439 - val_loss: 0.5869 - val_accuracy: 0.8101
# Epoch 11/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.4288 - accuracy: 0.8505 - val_loss: 0.5610 - val_accuracy: 0.8175
# Epoch 12/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.3991 - accuracy: 0.8606 - val_loss: 0.5144 - val_accuracy: 0.8276
# Epoch 13/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.3796 - accuracy: 0.8679 - val_loss: 0.5374 - val_accuracy: 0.8259
# Epoch 14/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.3656 - accuracy: 0.8708 - val_loss: 0.4940 - val_accuracy: 0.8365
# Epoch 15/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.3472 - accuracy: 0.8772 - val_loss: 0.4914 - val_accuracy: 0.8371
# Epoch 16/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.3338 - accuracy: 0.8829 - val_loss: 0.4841 - val_accuracy: 0.8453
# Epoch 17/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.3220 - accuracy: 0.8857 - val_loss: 0.4976 - val_accuracy: 0.8421
# Epoch 18/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.3076 - accuracy: 0.8914 - val_loss: 0.4980 - val_accuracy: 0.8396
# Epoch 19/50
# 782/782 [==============================] - 14s 19ms/step - loss: 0.3016 - accuracy: 0.8932 - val_loss: 0.4828 - val_accuracy: 0.8437
# Epoch 20/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.2866 - accuracy: 0.8973 - val_loss: 0.4876 - val_accuracy: 0.8444
# Epoch 21/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.2818 - accuracy: 0.8988 - val_loss: 0.4702 - val_accuracy: 0.8482
# Epoch 22/50
# 782/782 [==============================] - 15s 20ms/step - loss: 0.2694 - accuracy: 0.9046 - val_loss: 0.4780 - val_accuracy: 0.8493
# Epoch 23/50
# 782/782 [==============================] - 15s 20ms/step - loss: 0.2596 - accuracy: 0.9070 - val_loss: 0.4612 - val_accuracy: 0.8545
# Epoch 24/50
# 782/782 [==============================] - 15s 20ms/step - loss: 0.2551 - accuracy: 0.9084 - val_loss: 0.4712 - val_accuracy: 0.8513
# Epoch 25/50
# 782/782 [==============================] - 15s 20ms/step - loss: 0.2472 - accuracy: 0.9112 - val_loss: 0.4676 - val_accuracy: 0.8536
# Epoch 26/50
# 782/782 [==============================] - 15s 20ms/step - loss: 0.2420 - accuracy: 0.9135 - val_loss: 0.4688 - val_accuracy: 0.8523
# Epoch 27/50
# 782/782 [==============================] - 15s 20ms/step - loss: 0.2345 - accuracy: 0.9160 - val_loss: 0.4863 - val_accuracy: 0.8552
# Epoch 28/50
# 782/782 [==============================] - 15s 20ms/step - loss: 0.2279 - accuracy: 0.9190 - val_loss: 0.5189 - val_accuracy: 0.8465
# Epoch 29/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.2241 - accuracy: 0.9208 - val_loss: 0.4847 - val_accuracy: 0.8532
# Epoch 30/50
# 782/782 [==============================] - 15s 20ms/step - loss: 0.2234 - accuracy: 0.9209 - val_loss: 0.4823 - val_accuracy: 0.8555
# Epoch 31/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.2142 - accuracy: 0.9225 - val_loss: 0.4963 - val_accuracy: 0.8530
# Epoch 32/50
# 782/782 [==============================] - 15s 20ms/step - loss: 0.2071 - accuracy: 0.9254 - val_loss: 0.5064 - val_accuracy: 0.8546
# Epoch 33/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.2084 - accuracy: 0.9253 - val_loss: 0.4622 - val_accuracy: 0.8618
# Epoch 34/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.2034 - accuracy: 0.9266 - val_loss: 0.4713 - val_accuracy: 0.8589
# Epoch 35/50
# 782/782 [==============================] - 15s 20ms/step - loss: 0.1960 - accuracy: 0.9291 - val_loss: 0.5059 - val_accuracy: 0.8550
# Epoch 36/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.1908 - accuracy: 0.9314 - val_loss: 0.4864 - val_accuracy: 0.8573
# Epoch 37/50
# 782/782 [==============================] - 15s 20ms/step - loss: 0.1922 - accuracy: 0.9315 - val_loss: 0.5109 - val_accuracy: 0.8527
# Epoch 38/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.1852 - accuracy: 0.9342 - val_loss: 0.5043 - val_accuracy: 0.8538
# Epoch 39/50
# 782/782 [==============================] - 15s 20ms/step - loss: 0.1864 - accuracy: 0.9330 - val_loss: 0.5293 - val_accuracy: 0.8491
# Epoch 40/50
# 782/782 [==============================] - 15s 20ms/step - loss: 0.1834 - accuracy: 0.9345 - val_loss: 0.5020 - val_accuracy: 0.8572
# Epoch 41/50
# 782/782 [==============================] - 15s 20ms/step - loss: 0.1773 - accuracy: 0.9368 - val_loss: 0.5102 - val_accuracy: 0.8568
# Epoch 42/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.1739 - accuracy: 0.9376 - val_loss: 0.5151 - val_accuracy: 0.8557
# Epoch 43/50
# 782/782 [==============================] - 15s 20ms/step - loss: 0.1743 - accuracy: 0.9372 - val_loss: 0.4990 - val_accuracy: 0.8553
# Epoch 44/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.1722 - accuracy: 0.9390 - val_loss: 0.5123 - val_accuracy: 0.8563
# Epoch 45/50
# 782/782 [==============================] - 15s 20ms/step - loss: 0.1662 - accuracy: 0.9402 - val_loss: 0.5028 - val_accuracy: 0.8577
# Epoch 46/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.1628 - accuracy: 0.9409 - val_loss: 0.5300 - val_accuracy: 0.8500
# Epoch 47/50
# 782/782 [==============================] - 15s 20ms/step - loss: 0.1666 - accuracy: 0.9408 - val_loss: 0.4976 - val_accuracy: 0.8583
# Epoch 48/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.1605 - accuracy: 0.9429 - val_loss: 0.4997 - val_accuracy: 0.8635
# Epoch 49/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.1631 - accuracy: 0.9418 - val_loss: 0.4929 - val_accuracy: 0.8602
# Epoch 50/50
# 782/782 [==============================] - 15s 20ms/step - loss: 0.1584 - accuracy: 0.9422 - val_loss: 0.5145 - val_accuracy: 0.8573
# 79/79 [==============================] - 1s 7ms/step - loss: 0.5145 - accuracy: 0.8573
#
# Test score: 0.5144748091697693
# Test accuracy: 0.8572999835014343
